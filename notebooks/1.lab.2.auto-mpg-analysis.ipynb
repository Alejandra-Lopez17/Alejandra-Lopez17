# %% [markdown]
# <div
#   style="
#     background-color: #f0f0f0;
#     color:rgb(56, 56, 56);
#     padding: 8px;
#     display: flex;
#     align-items: center;
#     gap: 100px;
#   "
# >
#   <img src="./images/brand.svg" style="max-height: 80px;">
#   <strong>
#     AI Saga: Data Science and Machine Learning</br>
#     1.lab.2. Auto MPG Analysis
#   </strong>
# </div>

# %% [markdown]
# ### Background
#
# You will be working with the Auto MPG dataset containing fuel consumption information in miles per gallon (MPG) and other attributes for various car models.
# The dataset includes:
# - 398 instances
# - 8 attributes including MPG, cylinders, displacement, horsepower, weight, acceleration, model year and origin
#
# ### Description
# Your task is to perform an exploratory data analysis using Python. You should use libraries such as `pandas`, `numpy`, and `matplotlib` to:
# - Analyze the distribution of features
# - Identify correlations between variables
# - Explore relationships between features and MPG
# - Create meaningful visualizations to support your findings
#
# ### Deliverables
# - A **ipynb** (Jupyter Notebook) file called **auto-mpg-analysis.ipynb** that contains your code and analysis.
# - The **notebook** should be self-contained and include one paragraph summarizing the main findings of your analysis.
# - Use the provided **auto-mpg-analysis.ipynb** template as a starting point.

# %%
# ⚠️ IMPORTANT NOTICE FOR STUDENTS ⚠️
#
# Please make sure to check the official instructions for this assignment in Canvas LMS
# as they may have been updated or changed. The instructions above are provided for
# reference only and may not reflect the most current requirements.
#
# Always refer to Canvas LMS for:
# - Latest assignment requirements
# - Due dates
# - Grading criteria
# - Any special instructions
#
# When in doubt, ask your instructor for clarification.

from seaborn import load_dataset

# %%
df = load_dataset("mpg")
df.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# estructura general del DataFrame

df.info()
df.isnull().sum()
df.duplicated().sum()

# %%
# Histogramas de las características
df.hist(figsize=(20, 15), bins=30)
plt.show()

# %%
# Verificar tipos de datos
print(df.dtypes)

# %%
# Seleccionar solo columnas numéricas
df_numeric = df.select_dtypes(include=[np.number])

corr_matrix = df_numeric.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Codificación one-hot para la columna 'origin'

df_encoded = pd.get_dummies(df, columns=["origin"], drop_first=True)

df_numeric = df_encoded.select_dtypes(include=[np.number])

corr_matrix = df_numeric.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Scatter plot de MPG vs cilindrada
sns.scatterplot(x="displacement", y="mpg", data=df)
plt.title("Relación entre Cilindrada y MPG")
plt.show()

# %%
# Pairplot de características seleccionadas
sns.pairplot(df[["mpg", "cylinders", "displacement", "weight", "acceleration"]])
plt.show()

# %% [markdown]
# Resumen de Hallazgos
#
# Distribucion de Caracteristicas:
#
# Las caracteristicas numéricas tienen distribuciones asimétricas, con valores concentrados en ciertos rangos (por ejemplo, cylinders tiende a tener valores de 4, 6 u 8)
#
# Correlaciones:
#
# mpg esta fuertemente correlacionado de manera inversa con cylinders, displacement, horsepower y weight. Esto sugiere que los automoviles mas grandes y potentes tienden a ser menos eficientes en términos de consumo de combustible
#
# mpg tiene una correlacion positiva con model_year, lo que indica que los automoviles mas nuevos son mas eficientes
#
# Relaciones entre Variables:
#
# Los graficos de dispersion y pairplots confirman que mpg esta inversamente relacionado con caracteristicas como displacement y weight
#
# La relacion entre mpg y acceleration es menos clara, aunque parece haber una ligera tendencia positiva
#
# Valores Nulos:
#
# La columna horsepower tiene 6 valores nulos, lo que debe manejarse antes de realizar analisis adicionales o modelado
